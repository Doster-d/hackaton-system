# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")
model.export(format="engine", dynamic=True, int8=True)

model = YOLO("yolo11n-pose.pt")
model.export(format="engine", dynamic=True, int8=True)
# Out:
# WARNING ⚠️ TensorRT requires GPU export, automatically assigning device=0
# Ultralytics 8.3.233 🚀 Python-3.12.12 torch-2.9.1+cu128 CUDA:0 (NVIDIA H100 PCIe, 81079MiB)
# WARNING ⚠️ 'dynamic=True' model with 'format=engine' requires max batch size, i.e. 'batch=16'
# WARNING ⚠️ INT8 export requires a missing 'data' arg for calibration. Using default 'data=coco8.yaml'.
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
# PyTorch: starting from 'yolo11n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (5.4 MB)
#
# ONNX: starting export with onnx 1.19.1 opset 20...
# ONNX: slimming with onnxslim 0.1.77...
# ONNX: export success ✅ 1.0s, saved as 'yolo11n.onnx' (10.1 MB)
#
# TensorRT: starting export with TensorRT 10.14.1.48.post1...
# TensorRT: collecting INT8 calibration images from 'data=coco8.yaml'
# Fast image access ✅ (ping: 0.0±0.0 ms, read: 2486.2±550.3 MB/s, size: 54.0 KB)
# ...

# %%
model_load = YOLO("yolo11n-pose.engine")
model_load2 = YOLO("yolo11n.engine")
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
